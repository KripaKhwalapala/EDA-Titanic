# %%
import pandas as pd

# %% [markdown]
# ## Problem 1:
# Below, calculate the mean and standard deviation for the age of the passengers on the Titanic. Once you have completed the calculations, please use a markdown box to interpret the results.

# %%
Titanic=pd.read_csv("Titanic.csv")
Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
m=Titanic["Age"].mean()
s=Titanic["Age"].std()

print("Mean=", m)
print("Standard deviation=", s)
# Out:
# Mean= 29.69911764705882
# Standard deviation= 14.526497332334044

# %% [markdown]
# - **Hence, mean and standard deviation for the age of the passengers on the Titanic is 29.69 and 14.52 respectively.**
#
#
# The mean age of 29.69 indicates that, on average, the age of the passengers is around 29.69 years.
#
# The standard deviation of 14.52 reflects the variability or spread of ages around the mean. A higher standard deviation suggests that the ages of the passengers are more widely dispersed from the mean age of 29.69.

# %% [markdown]
# ## Problem 2:
# Below, calculate the median and the range for the age of the passengers on the Titanic. Once you have completed the calculations, please use a markdown box to interpret the results.

# %%
med=Titanic["Age"].median()
r=Titanic["Age"].max()-Titanic["Age"].min()
print("Median=", med)
print("Range=", r)
# Out:
# Median= 28.0
# Range= 79.58

# %% [markdown]
# - **Hence, median and range for the age of the passengers on the Titanic is 28 and 79.58 respectively.**
#
# The median age of 28 indicates that 50% of the passengers were 28 years old or younger, and the other 50% were 28 years old or older. Unlike the mean, the median is not affected by extreme values and provides a robust measure of central tendency.
#
#
# The range of 79.58 represents the difference between the maximum and minimum ages in the dataset. In this case, it suggests that the oldest passenger was 79.58 years older than the youngest passenger. The range provides a simple measure of dispersion but may be influenced by outliers.

# %% [markdown]
# ## Problem 3:
# Graph the age of the passengers using a density plot. Describe/interpret the plot in a markdown box.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.kdeplot(Titanic["Age"], fill = True)

plt.title ("Density plot of Age of passengers")
# Out:
# Text(0.5, 1.0, 'Density plot of Age of passengers')

# %% [markdown]
# ### Density Plot of Age
#
# The density plot illustrates the distribution of passenger ages:
#
# - **X-Axis (Age)**: Represents the range of ages of the passengers.
# - **Y-Axis (Density)**: Represents the density of passengers within each age group, indicating how common or uncommon certain ages are among the passengers.
#
# #### Key Observations
#
# 1. **Age Distribution**:
#    The density plot shows how the ages are distributed across the passengers. The shape of the curve indicates the frequency of different age groups.
#
#
# 2. **Mode**:
#    The peak of the density plot represents the mode, or the most common age group among the passengers. For example, if the peak occurs around 30 years, it means that there are many passengers in that age group.
#
#
# 3. **Spread**:
#    The width of the plot indicates the spread of ages. A wider spread suggests a more diverse age range among the passengers, while a narrower spread indicates less variation in ages.
#
#
# 4. **Tails**:
#    The tails of the density plot show the distribution of the youngest and oldest passengers. If the tails are long, it suggests that there are passengers at both very young and very old ages.
#
#
# #### Implications
#
# - **Demographic Insights**:
#   The density plot provides valuable insights into the age demographics of the passengers. Identifying the most common age groups can help in understanding the target audience or clientele.
#
# - **Service Planning**:
#   Knowing the age distribution can assist in planning services and amenities that cater to the most common age groups. For instance, a significant number of young passengers might indicate a need for family-friendly facilities, while a larger number of older passengers might necessitate more accessibility features.
#
# - **Marketing Strategies**:
#   Marketing efforts can be tailored based on the age distribution. For example, promotional activities can be focused on the age groups that are most prevalent among the passengers.
#
# This density plot provides a clear visualization of the age distribution among passengers, highlighting key demographic characteristics and enabling informed decision-making.

# %% [markdown]
# ## Problem 4:
# Graph the age of the passengers using a histogram with an appropriate bin width. Describe/interpret the plot in a markdown box.

# %%
age_counts= Titanic["Age"].value_counts()
age_counts
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
# Create the histogram with seaborn
plt.figure(figsize=(10, 6))
sns.histplot(Titanic['Age'], bins=10, kde=True, color='Blue', edgecolor='black')

# Add labels and title
plt.title('Histogram of Passenger Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ### Histogram of Passenger Ages
#
# The histogram shows the distribution of passenger ages in the sample dataset. Here's an interpretation of the plot:
#
# - **Bin Width**: The bin width was chosen to be 10, which groups the ages into intervals of 10 years. This provides a clear view of the age distribution without making the bins too narrow or too wide.
# - **Age Distribution**: The majority of the passengers are in the age ranges of 20-30 and 30-40, indicating a higher frequency of passengers in these age groups.
# - **Outliers and Gaps**: There are fewer passengers in the age ranges below 20 and above 50, indicating these age groups are less represented in the dataset.
# - **Peak Frequency**: The highest frequency is observed in the 20-30 age range, suggesting that this age group is the most common among the passengers.
#
# Overall, the histogram provides a clear visualization of the age distribution, allowing us to see the most and least common age groups among the passengers.

# %% [markdown]
# ## Problem 5:
# Graph the age of the passengers using a boxplot. Describe/interpret the plot in a markdown box.

# %%
plt.figure(figsize=(8,6))
sns.boxplot (x=Titanic['Age'])

plt.title('Box Plot of Age of Passenger')
plt.xlabel('Age')

plt.show()

# %%
sns.violinplot(Titanic['Age'].dropna())
# Out:
# <Axes: >

# %% [markdown]
# ## Problem 6:
# Choose measures of center and spread to analyze the Fare variable. Interpret the results in a markdown box.

# %%
#measures of center 

mean_fare = Titanic['Fare'].mean()
median_fare = Titanic['Fare'].median()
print(f"Mean Fare: {mean_fare:.2f}")
print(f"Median Fare: {median_fare:.2f}")


##mode also

#measures of spread

std_dev_fare = Titanic['Fare'].std()
iqr_fare = Titanic['Fare'].quantile(0.75) - Titanic['Fare'].quantile(0.25)
range_fare = Titanic['Fare'].max() - Titanic['Fare'].min()
print(f"Standard Deviation of Fare: {std_dev_fare:.2f}")
print(f"Interquartile Range (IQR) of Fare: {iqr_fare:.2f}")
print(f"Range of Fare: {range_fare:.2f}")
# Out:
# Mean Fare: 32.20
# Median Fare: 14.45
# Standard Deviation of Fare: 49.69
# Interquartile Range (IQR) of Fare: 23.09
# Range of Fare: 512.33

# %% [markdown]
# #### Interpretation:
# - The **mean fare** provides an overall average, but given the standard deviation and range, it is evident that there is significant variability in the fare amounts.
# - The **median fare** being lower than the mean suggests a right-skewed distribution, where a few high fares increase the mean.
# - The **standard deviation** and **IQR** both indicate considerable spread, with the IQR focusing on the middle 50% and the standard deviation giving a broader measure of dispersion.
# - The **range** highlights the wide disparity between the lowest and highest fares, suggesting the presence of outliers or a diverse pricing structure.
#
# Overall, the measures of center and spread provide a comprehensive view of the fare distribution, indicating both central tendencies and variability within the data.

# %% [markdown]
# ## Problem 7:
# Choose the best graph to visualize the Fare variable. Interpret the results in a markdown box.

# %%
#Let's choose Histogram

plt.figure(figsize=(10, 6))
sns.histplot(Titanic['Fare'], bins=10, kde=True, color='blue', edgecolor='black')


plt.title('Histogram of Fares')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## kurtosis ( check about this)

# %% [markdown]
# ### Interpretation of the Histogram of Fares
#
# The histogram of the Fare variable shows the frequency distribution of passenger fares:
#
# - **X-Axis (Fare)**: Represents the range of fare amounts paid by passengers.
# - **Y-Axis (Frequency)**: Represents the number of passengers who paid fares within each fare range.

# %% [markdown]
# ## Problem 8:
# Use side-by-side density plots and side-by-side boxplots, answer the following question: Is there a relationship between Age and Pclass?

# %%
# bins = [0, 18, 30, 40, 50, 60, 70]
# labels = ['0-18', '19-30', '31-40', '41-50', '51-60', '61-70']
# Titanic['age_group'] = pd.cut(Titanic['Age'], bins=bins, labels=labels, right=False)

# %%
#Create Side-by-Side Density Plots

plt.figure(figsize=(10, 6))
sns.kdeplot(data=Titanic , x='Age', hue='Pclass', fill=True, common_norm=False, palette='viridis', alpha=0.5)
plt.title('Density Plot of Pclass by Age Group')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# - **First Class**: The density curve for first-class passengers shows where their ages are concentrated. For instance, if the peak is around 40 years, it means that a significant number of first-class passengers are around that age.
# - **Second Class**: The density curve for second-class passengers will reveal their age distribution, showing any significant differences or similarities compared to other classes.
# - **Third Class**: The density curve for third-class passengers will highlight their age distribution, which might differ from the other classes.

# %% [markdown]
# X-axis (Age): This will show the ages of the passengers.
#
# Y-axis (Density): This will show the density of passengers at each age.
#
# Hue (Pclass): Different curves/colors for each passenger class.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Pclass', y='Age', data=Titanic, palette='viridis')
plt.title('Box Plot of Age by Pclass')
plt.xlabel('Pclass')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ### Box Plot of Age by Pclass
#
# The box plot visualizes the distribution of ages within each passenger class (Pclass):
#
# - **X-Axis (Pclass)**: Represents the passenger class (1st, 2nd, and 3rd class).
# - **Y-Axis (Age)**: Represents the ages of the passengers.
#
# #### Interpretation
#
# - **Median**: The line inside each box represents the median age for that class.
# - **Interquartile Range (IQR)**: The box spans from the 25th percentile (Q1) to the 75th percentile (Q3), representing the middle 50% of the data.
# - **Whiskers**: The lines extending from the box show the range of ages within 1.5 times the IQR from the quartiles.
# - **Outliers**: Individual points outside the whiskers represent outliers, which are ages significantly different from the rest of the data.
#
# #### Class-Specific Insights
#
# - **First Class**: The box plot for first-class passengers might show a higher median age and a wider IQR, indicating a broader age range among first-class passengers.
# - **Second Class**: The box plot for second-class passengers might have a slightly lower median age compared to first class, with a narrower IQR.
# - **Third Class**: The box plot for third-class passengers might show the lowest median age and possibly a narrower IQR, indicating a younger and more consistent age range.
#
# This visualization helps in understanding the age distribution and variability within each passenger class, highlighting differences in age demographics among the classes.

# %% [markdown]
# ## Problem 9:
# Use an appropriate graph to answer the following question: Is there a relationship between Age and Gender?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Sex', y='Age', data= Titanic, palette='viridis')
plt.title('Box Plot of Age by Gender(Sex)')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ### Box Plot of Age by Gender
#
# The box plot visualizes the distribution of ages within each gender group:
#
# - **X-Axis (Gender)**: Represents the gender of the passengers (Male and Female).
# - **Y-Axis (Age)**: Represents the ages of the passengers.
#
# #### Key Observations
#
# 1. **Median**:
#    - The line inside each box represents the median age for that gender group.
#    - For example, if the median age for males is 30 and for females is 25, this means that half of the male passengers are younger than 30 and half are older, while for females, half are younger than 25 and half are older.
#
# 2. **Interquartile Range (IQR)**:
#    - The box spans from the 25th percentile (Q1) to the 75th percentile (Q3), representing the middle 50% of the data.
#    - A wider box indicates more variability in ages within that gender group, while a narrower box indicates less variability.
#
# 3. **Whiskers**:
#    - The lines extending from the box show the range of ages within 1.5 times the IQR from the quartiles.
#    - The whiskers provide a sense of the spread of the majority of the data.
#
# 4. **Outliers**:
#    - Individual points outside the whiskers represent outliers, which are ages significantly different from the rest of the data.
#    - For example, a very young or very old passenger compared to the rest might be shown as an outlier.
#
# #### Gender-Specific Insights
#
# - **Male**:
#   - The median age, IQR, and presence of outliers for males can be observed. If the median age is higher for males, it suggests that the male passengers tend to be older compared to females.
#   - The spread and outliers can indicate the diversity in ages among male passengers.
#
# - **Female**:
#   - Similarly, the median age, IQR, and outliers for females can provide insights into the age distribution among female passengers.
#   - A lower median age for females indicates that female passengers tend to be younger compared to males.
#
# #### Implications
#
# - **Demographic Insights**:
#   - Understanding the age distribution by gender helps in identifying key demographic groups.
#   - If there is a significant difference in median ages, it could reflect different age preferences or demographics for each gender.
#
# - **Service Planning**:
#   - Age distributions can inform service planning and amenities. For example, if female passengers are generally younger, family-friendly services might be more relevant.
#
# - **Marketing Strategies**:
#   - Marketing efforts can

# %% [markdown]
# ## Problem 10:
# Use an appropriate graph to answer the following question: Is there a relationship between Fare and Gender?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Sex', y='Fare', data= Titanic, palette='viridis')
plt.title('Box Plot of Fare by Gender(Sex)')
plt.xlabel('Sex')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# **Gender Differences in Fare Distribution:**
#
# - Median Fare:
#
# The median fare for female passengers appears to be slightly lower compared to male passengers. This suggests that, on average, female passengers tend to pay less for their tickets compared to male passengers.
#
# - Interquartile Range (IQR):
#
# The spread of fares within male passengers, as indicated by the IQR, seems slightly wider compared to female passengers. This means that there is more variability in fares among male passengers compared to females.
#
# - Outliers:
#
# There seem to be more outliers among male passengers, particularly towards the higher fare range, indicating that there are some male passengers who pay significantly higher fares compared to the majority.

# %% [markdown]
# ## Problem 11:
# Describe the difference in Fare for each Pclass (the class of the ticket).

# %%
##let us first group by the Pclass
grouped = Titanic.groupby('Pclass')['Fare'].describe()
print(grouped)
# Out:
#         count       mean        std  min       25%      50%   75%       max
# Pclass
# 1       216.0  84.154687  78.380373  0.0  30.92395  60.2875  93.5  512.3292
# 2       184.0  20.662183  13.417399  0.0  13.00000  14.2500  26.0   73.5000
# 3       491.0  13.675550  11.778142  0.0   7.75000   8.0500  15.5   69.5500

# %%
#then let us show by using Box plot
mean_fares = Titanic.groupby('Pclass')['Fare'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Pclass', y='Fare', data=mean_fares, palette='viridis')
plt.title('Mean Fare by Pclass')
plt.xlabel('Pclass')
plt.ylabel('Mean Fare')
plt.show()

# %% [markdown]
# - **1st Class**: The fares for first class have the highest median and show a wide range, indicating variability in fare prices within this class. The presence of outliers suggests that some first-class tickets are significantly more expensive.
#
# - **2nd Class**: The fares for second class are lower than first class and have a narrower interquartile range, indicating more consistency in fare prices.
#
# - **3rd Class**: The fares for third class are the lowest and also show a narrow interquartile range, indicating consistent pricing within this class.

# %% [markdown]
# ## Problem 12:
# Describe the difference in Fare for each embarkment location.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Embarked', y='Fare', data=Titanic)
plt.title('Box Plot of Fare by Embarkment Location')
plt.xlabel('Embarked')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# **Fare Differences by Embarkment Location:**
#
# - Median Fare:
#
# The median fare for passengers embarking from different locations varies. This suggests that there may be differences in ticket prices based on the embarkation location.
#
# - Interquartile Range (IQR):
#
# The spread of fares within each embarkation location, as indicated by the height of the boxes, varies. Some locations have wider interquartile ranges, indicating more variability in ticket prices.
#
# - Outliers:
#
# The presence of outliers in certain embarkation locations, as shown by the individual points beyond the whiskers, suggests that some passengers from those locations paid significantly higher fares compared to others.
#
# - Whiskers:
#
# The length of the whiskers indicates the range of "typical" fare values for each embarkation location. Longer whiskers suggest a broader range of fare values, while shorter whiskers suggest a narrower range.

# %% [markdown]
# ## Problem 13:
# Did the same number of men and women come from each embarkment location?

# %%
embarked_sex_counts = Titanic.groupby(['Embarked', 'Sex']).size().unstack()
embarked_sex_counts
# Out:
# Sex       female  male
# Embarked
# C             73    95
# Q             36    41
# S            203   441

# %% [markdown]
# - **So looking at the counts here, we can say that the distribution is uneven.**

# %% [markdown]
# ## Problem 14:
# Who was more likely to survive, men or women?

# %%
survival_rates = Titanic.groupby('Sex')['Survived'].mean()
survival_rates
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# - **Hence, women were more likely to survive**

# %% [markdown]
# ## Problem 15:
# How was the age of the survivors distributed?

# %%
plt.figure(figsize=(10, 6))
sns.histplot(Titanic[Titanic['Survived'] == 1]['Age'].dropna(), kde=True, bins=10, color='blue')
plt.title('Distribution of Age for Survivors')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Interpretation:**
#
#
# - Shape of Distribution:
# The distribution appears to be skewed to the right, with a long tail towards older ages. This suggests that there were relatively fewer survivors among older age groups compared to younger ones.
#
#
#
# - Central Tendency: The peak of the distribution (the tallest bar) is around the early to mid-20s, indicating that a significant proportion of survivors belonged to this age group. This suggests that young adults in their 20s were more likely to survive the event.
#
#
# - Spread: The distribution spans a wide range of ages, from infants to elderly individuals. However, the frequency decreases as age increases, indicating that there were fewer survivors among older age groups.
#
#
# - KDE Curve: The kernel density estimation (KDE) curve provides a smoothed estimate of the probability density function. It visually represents the distribution pattern of survivor ages, showing the general trend of decreasing density with increasing age.

# %% [markdown]
# ## Problem 16:
# Were people who paid more for a ticket more likely to survive?

# %%
# Define fare groups (you can adjust the threshold as needed)

fare_threshold = Titanic['Fare'].median()  # Use median fare as the threshold
Titanic['FareGroup'] = pd.cut(Titanic['Fare'], bins=[0, fare_threshold, Titanic['Fare'].max()], labels=['Low Fare', 'High Fare'])

# Calculate survival rates for each fare group
survival_rates = Titanic.groupby('FareGroup')['Survived'].mean()

survival_rates
# Out:
# FareGroup
# Low Fare     0.256944
# High Fare    0.518018
# Name: Survived, dtype: float64

# %% [markdown]
# - **Hence, yes. People who paid more for a ticket were more likely to survive.**

# %% [markdown]
# ## crosstab use garera try garne

# %% [markdown]
# ## Problem 17:
# Were people with 1st class tickets more likely to survive?

# %%
survival_rates = Titanic.groupby('Pclass')['Survived'].mean()

survival_rates
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# - **Hence, yes. People with 1st class tickets were more likely to survive.**

# %% [markdown]
# ## Problem 18:
# Create your own interesting question and find an answer.

# %% [markdown]
# - **How many males and females were in 1st class?**

# %%
# Filter the data for passengers in 1st class
first_class_passengers = Titanic[Titanic['Pclass'] == 1]

# Count the number of males and females in 1st class
male_count = first_class_passengers[first_class_passengers['Sex'] == 'male'].shape[0]
female_count = first_class_passengers[first_class_passengers['Sex'] == 'female'].shape[0]

print("Number of males in 1st class:", male_count)
print("Number of females in 1st class:", female_count)
# Out:
# Number of males in 1st class: 122
# Number of females in 1st class: 94

# %% [markdown]
# ## Problem 19:
# What percentage of the passengers were men? What percentage were women?

# %%
# Count the number of male and female passengers
male_count = (Titanic['Sex'] == 'male').sum()
female_count = (Titanic['Sex'] == 'female').sum()

# Calculate the percentage of male and female passengers
total_passengers = len(Titanic)
male_percentage = (male_count / total_passengers) * 100
female_percentage = (female_count / total_passengers) * 100

print("Percentage of passengers who were men:", male_percentage)
print("Percentage of passengers who were women:", female_percentage)
# Out:
# Percentage of passengers who were men: 64.75869809203144
# Percentage of passengers who were women: 35.24130190796858

# %% [markdown]
# ## Problem 20:
# What percentage of the passengers survived?

# %%
# Count the number of passengers who survived
survived_count = Titanic['Survived'].sum()

# Calculate the percentage of passengers who survived
total_passengers = len(Titanic)
survival_percentage = (survived_count / total_passengers) * 100

print("Percentage of passengers who survived:", survival_percentage)
# Out:
# Percentage of passengers who survived: 38.38383838383838

# %% [markdown]
# ## Problem 21:
# What percentage of the passengers were in 1st class? 2nd class? 3rd class?

# %%
# Count the number of passengers in each class
class_counts = Titanic['Pclass'].value_counts()

# Calculate the percentage of passengers in each class
total_passengers = len(Titanic)
class_percentages = (class_counts / total_passengers) * 100

print("Percentage of passengers in 1st class:", class_percentages[1])
print("Percentage of passengers in 2nd class:", class_percentages[2])
print("Percentage of passengers in 3rd class:", class_percentages[3])
# Out:
# Percentage of passengers in 1st class: 24.242424242424242
# Percentage of passengers in 2nd class: 20.65095398428732
# Percentage of passengers in 3rd class: 55.106621773288445
